# %% [markdown]
# # Make Dataset

# %% [markdown]
# ## Pre

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# %% [markdown]
# ## Dataset burnt

# %%
# go to folder data dec to feb
folder_path = 'DATA'
# burnt, danger, warning, advice data
burnt_path = os.path.join(folder_path, 'Burnt Areas.csv')
burnt = pd.read_csv(burnt_path, sep=';')# on_bad_lines='skip') # on_bad_lines='skip' will skip lines that cause errors.
burnt['created_at'] = pd.to_datetime(burnt['created_at']).dt.strftime('%Y/%m/%d')
burnt
# Out:
# <ipython-input-4-3bdca8b34e98>:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   burnt['created_at'] = pd.to_datetime(burnt['created_at']).dt.strftime('%Y/%m/%d')
#      created_at      suburb      time   status                       location  \
# 0    2023/12/01    Wanneroo  10:38:00   ADVICE        JANDABUP and MARIGINIUP
# 1    2023/12/01  Mariginiup  10:38:00   ADVICE        JANDABUP and MARIGINIUP
# 2    2023/12/01   Hamersley  10:45:00   ADVICE                HAMERSLEY RANGE
# 3    2023/12/01    Wanneroo  11:51:00   ADVICE        JANDABUP and MARIGINIUP
# 4    2023/12/01  Mariginiup  11:51:00   ADVICE        JANDABUP and MARIGINIUP
# ..          ...         ...       ...      ...                            ...
# 992  2024/01/17   Hamersley  10:20:00   ADVICE  NANUTARRA and HAMERSLEY RANGE
# ...

# %%
# jumlah status per bulan
burnt['created_at'] = pd.to_datetime(burnt['created_at'])
monthly_status_counts = burnt.groupby(burnt['created_at'].dt.to_period('M'))['status'].value_counts().unstack(fill_value=0)
monthly_status_counts
# Out:
# status      ADVICE  BURNT  EMERGENCY WARNING  WATCH AND ACT
# created_at
# 2023-12        241     51                 99            132
# 2024-01         91     35                  2             83
# 2024-02        158     30                  8             67

# %%
burnt2_path="/DATA/cleanbushfire-martojan.csv"
burnt2 = pd.read_csv(burnt2_path, delimiter=';')# on_bad_lines='skip') # on_bad_lines='skip' will skip lines that cause errors.
burnt2['created_at'] = pd.to_datetime(burnt2['created_at']).dt.strftime('%Y/%m/%d')
burnt2
# Out:
# <ipython-input-6-077933129b92>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   burnt2['created_at'] = pd.to_datetime(burnt2['created_at']).dt.strftime('%Y/%m/%d')
#      conversation_id_str  created_at  favorite_count    id_str  \
# 0               7,60E+19  2024/03/04               2  1,76E+18
# 1               7,60E+19  2024/03/03               0  1,76E+18
# 2               7,60E+19  2024/03/03               1  1,76E+18
# 3               7,60E+19  2024/03/01               1  1,76E+18
# 4               7,60E+19  2024/03/02               0  1,76E+18
# ...                  ...         ...             ...       ...
# 6177            8,85E+22  2025/01/29               0  1,88E+18
# 6178            8,85E+22  2025/01/29               0  1,88E+18
# 6179            8,85E+22  2025/01/29               1  1,88E+18
# ...

# %%
burnt2 = burnt2[['created_at', 'time','suburb', 'status']]
burnt2
# Out:
#       created_at      time        suburb         status
# 0     2024/03/04  10:49 AM  Wanneroo              BURNT
# 1     2024/03/03   3:58 PM  Wanneroo             ADVICE
# 2     2024/03/03  10:05 AM  Wanneroo             ADVICE
# 3     2024/03/01  11:06 AM  Wanneroo             ADVICE
# 4     2024/03/02   3:22 PM  Wanneroo             ADVICE
# ...          ...       ...           ...            ...
# 6177  2025/01/29  12:51 AM  Orange Grove         ADVICE
# 6178  2025/01/29   1:16 AM  Orange Grove  WATCH AND ACT
# 6179  2025/01/29   1:19 AM  Orange Grove  WATCH AND ACT
# 6180  2025/01/29   1:52 AM  Orange Grove         ADVICE
# 6181  2025/01/29   3:35 AM  Orange Grove         ADVICE
#
# [6182 rows x 4 columns]

# %%
# jumlah status per bulan
burnt2['created_at'] = pd.to_datetime(burnt2['created_at'])
monthly_status_counts = burnt2.groupby(burnt2['created_at'].dt.to_period('M'))['status'].value_counts().unstack(fill_value=0)
monthly_status_counts
# Out:
# <ipython-input-8-9d1ab0371ad3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burnt2['created_at'] = pd.to_datetime(burnt2['created_at'])
# status      ADVICE  BURNT  EMERGENCY WARNING  WATCH AND ACT
# created_at
# 2024-03         82     22                 52             62
# 2024-04         64     15                  4              5
# 2024-05         12      6                  0              0
# 2024-07          3      3                  0              0
# 2024-09         14      0                  0              0
# 2024-10         10      0                  0              5
# 2024-11         44      0                  6             18
# 2024-12         81      0                 13             36
# ...

# %%
burnt = burnt[['created_at', 'time','suburb', 'status']]
burnt
# Out:
#     created_at      time      suburb   status
# 0   2023-12-01  10:38:00    Wanneroo   ADVICE
# 1   2023-12-01  10:38:00  Mariginiup   ADVICE
# 2   2023-12-01  10:45:00   Hamersley   ADVICE
# 3   2023-12-01  11:51:00    Wanneroo   ADVICE
# 4   2023-12-01  11:51:00  Mariginiup   ADVICE
# ..         ...       ...         ...      ...
# 992 2024-01-17  10:20:00   Hamersley   ADVICE
# 993 2024-01-17  15:09:00   Hamersley   ADVICE
# 994 2024-01-24  10:52:00  South Lake    BURNT
# 995 2024-01-24  15:52:00    Gnangara    BURNT
# 996 2024-01-24  15:52:00       Lexia    BURNT
#
# [997 rows x 4 columns]

# %%
# Filter data for December, January and February
burnt_jan_feb = burnt[(burnt['created_at'].dt.month == 12)|(burnt['created_at'].dt.month == 1) | (burnt['created_at'].dt.month == 2)]

# Concatenate the filtered data with burnt2
combined = pd.concat([burnt_jan_feb, burnt2], ignore_index=True)
combined
# Out:
#      created_at      time        suburb         status
# 0    2023-12-01  10:38:00      Wanneroo         ADVICE
# 1    2023-12-01  10:38:00    Mariginiup         ADVICE
# 2    2023-12-01  10:45:00     Hamersley         ADVICE
# 3    2023-12-01  11:51:00      Wanneroo         ADVICE
# 4    2023-12-01  11:51:00    Mariginiup         ADVICE
# ...         ...       ...           ...            ...
# 7174 2025-01-29  12:51 AM  Orange Grove         ADVICE
# 7175 2025-01-29   1:16 AM  Orange Grove  WATCH AND ACT
# 7176 2025-01-29   1:19 AM  Orange Grove  WATCH AND ACT
# 7177 2025-01-29   1:52 AM  Orange Grove         ADVICE
# 7178 2025-01-29   3:35 AM  Orange Grove         ADVICE
#
# [7179 rows x 4 columns]

# %%
# Check for duplicates based on all columns
combined['suburb'] = combined['suburb'].str.strip()
combined['status'] = combined['status'].str.strip()
duplicates = combined[combined.duplicated(keep=False)]
combined.drop_duplicates(inplace=True)

# %%
clean_df = (
    combined
    .sort_values(by=['created_at', 'suburb', 'time'])  # Pastikan urut berdasarkan waktu
    .groupby(['created_at', 'suburb', 'status'])  # Kelompokkan berdasarkan Date, suburb, dan status
    .first()  # Ambil baris pertama dalam setiap kelompok
    .reset_index()  # Reset index setelah groupby
)
clean_df
# Out:
#      created_at        suburb             status      time
# 0    2023-12-01     Hamersley             ADVICE  10:45:00
# 1    2023-12-01    Mariginiup             ADVICE  10:38:00
# 2    2023-12-01      Wanneroo             ADVICE  10:38:00
# 3    2023-12-02     Hamersley             ADVICE  10:43:00
# 4    2023-12-02    Mariginiup             ADVICE  10:44:00
# ...         ...           ...                ...       ...
# 1891 2025-01-31    Ocean Reef  EMERGENCY WARNING   1:46 PM
# 1892 2025-01-31    Ocean Reef      WATCH AND ACT   3:07 PM
# 1893 2025-01-31  Orange Grove             ADVICE  10:00 AM
# 1894 2025-01-31  Orange Grove  EMERGENCY WARNING   1:46 PM
# 1895 2025-01-31  Orange Grove      WATCH AND ACT   5:15 PM
#
# [1896 rows x 4 columns]

# %%
clean_df = clean_df.rename(columns={'created_at': 'Date'})
clean_df['Date'] = pd.to_datetime(clean_df['Date'], errors='coerce')
clean_df['time'] = pd.to_datetime(clean_df['time'], errors='coerce').dt.hour
clean_df.loc[clean_df['time'] == 0, 'time'] = 24
clean_df
# Out:
# <ipython-input-13-a455a05feea1>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean_df['time'] = pd.to_datetime(clean_df['time'], errors='coerce').dt.hour
#            Date        suburb             status  time
# 0    2023-12-01     Hamersley             ADVICE    10
# 1    2023-12-01    Mariginiup             ADVICE    10
# 2    2023-12-01      Wanneroo             ADVICE    10
# 3    2023-12-02     Hamersley             ADVICE    10
# 4    2023-12-02    Mariginiup             ADVICE    10
# ...         ...           ...                ...   ...
# 1891 2025-01-31    Ocean Reef  EMERGENCY WARNING    13
# 1892 2025-01-31    Ocean Reef      WATCH AND ACT    15
# 1893 2025-01-31  Orange Grove             ADVICE    10
# 1894 2025-01-31  Orange Grove  EMERGENCY WARNING    13
# 1895 2025-01-31  Orange Grove      WATCH AND ACT    17
#
# ...

# %%
clean_df
# Out:
#            Date        suburb             status  time
# 0    2023-12-01     Hamersley             ADVICE    10
# 1    2023-12-01    Mariginiup             ADVICE    10
# 2    2023-12-01      Wanneroo             ADVICE    10
# 3    2023-12-02     Hamersley             ADVICE    10
# 4    2023-12-02    Mariginiup             ADVICE    10
# ...         ...           ...                ...   ...
# 1891 2025-01-31    Ocean Reef  EMERGENCY WARNING    13
# 1892 2025-01-31    Ocean Reef      WATCH AND ACT    15
# 1893 2025-01-31  Orange Grove             ADVICE    10
# 1894 2025-01-31  Orange Grove  EMERGENCY WARNING    13
# 1895 2025-01-31  Orange Grove      WATCH AND ACT    17
#
# [1896 rows x 4 columns]

# %%
# export combined to csv file

clean_df.to_csv('clean_data.csv', index=False)

# %%
# jumlah status per bulan
monthly_status_counts = clean_df.groupby(clean_df['Date'].dt.to_period('M'))['status'].value_counts().unstack(fill_value=0)
monthly_status_counts
# Out:
# status   ADVICE  BURNT  EMERGENCY WARNING  WATCH AND ACT
# Date
# 2023-12     121     40                 11             27
# 2024-01      53     35                  2             19
# 2024-02      73     30                  3             26
# 2024-03      51     22                  9             26
# 2024-04      32     14                  3              4
# 2024-05       9      6                  0              0
# 2024-07       2      2                  0              0
# 2024-09       4      0                  0              0
# 2024-10       4      0                  0              3
# 2024-11      26      0                  3              7
# 2024-12      36      0                  8             11
# 2025-01     682      0                198            294

# %%
import matplotlib.pyplot as plt
# Plotting
monthly_status_counts.plot(kind='bar', figsize=(15, 8))
plt.title('Number of Each Status Per Month')
plt.xlabel('Month')
plt.ylabel('Number of Status')
plt.xticks(rotation=45)
plt.legend(title='Status')
plt.tight_layout()
plt.show()

# %%
clean_df
# Out:
#            Date        suburb             status  time
# 0    2023-12-01     Hamersley             ADVICE    10
# 1    2023-12-01    Mariginiup             ADVICE    10
# 2    2023-12-01      Wanneroo             ADVICE    10
# 3    2023-12-02     Hamersley             ADVICE    10
# 4    2023-12-02    Mariginiup             ADVICE    10
# ...         ...           ...                ...   ...
# 1891 2025-01-31    Ocean Reef  EMERGENCY WARNING    13
# 1892 2025-01-31    Ocean Reef      WATCH AND ACT    15
# 1893 2025-01-31  Orange Grove             ADVICE    10
# 1894 2025-01-31  Orange Grove  EMERGENCY WARNING    13
# 1895 2025-01-31  Orange Grove      WATCH AND ACT    17
#
# [1896 rows x 4 columns]

# %%
weather_path = os.path.join(folder_path, 'w_station.xlsx')
weather_station = pd.read_excel(weather_path)
weather_station

# %%
clean_df['station'] = ''
clean_df
# Out:
#            Date        suburb             status  time station
# 0    2023-12-01     Hamersley             ADVICE    10
# 1    2023-12-01    Mariginiup             ADVICE    10
# 2    2023-12-01      Wanneroo             ADVICE    10
# 3    2023-12-02     Hamersley             ADVICE    10
# 4    2023-12-02    Mariginiup             ADVICE    10
# ...         ...           ...                ...   ...     ...
# 1891 2025-01-31    Ocean Reef  EMERGENCY WARNING    13
# 1892 2025-01-31    Ocean Reef      WATCH AND ACT    15
# 1893 2025-01-31  Orange Grove             ADVICE    10
# 1894 2025-01-31  Orange Grove  EMERGENCY WARNING    13
# 1895 2025-01-31  Orange Grove      WATCH AND ACT    17
#
# [1896 rows x 5 columns]

# %%
# Iterate through the 'clean_df' DataFrame
for index, row in clean_df.iterrows():

    suburb = row['suburb']

    # Cari baris yang sesuai di weather_station
    matching_rows = weather_station[weather_station['suburb'] == suburb]

    # Jika ada kecocokan, update clean_df
    if not matching_rows.empty:
        clean_df.loc[index, 'station'] = matching_rows.iloc[0]['Station Name']
clean_df['Date'] = pd.to_datetime(clean_df['Date']).dt.strftime('%Y/%m/%d')
clean_df
# Out:
#             Date        suburb             status  time     station
# 0     2023/12/01     Hamersley             ADVICE    10       Perth
# 1     2023/12/01    Mariginiup             ADVICE    10      Pearce
# 2     2023/12/01      Wanneroo             ADVICE    10       Perth
# 3     2023/12/02     Hamersley             ADVICE    10       Perth
# 4     2023/12/02    Mariginiup             ADVICE    10      Pearce
# ...          ...           ...                ...   ...         ...
# 1891  2025/01/31    Ocean Reef  EMERGENCY WARNING    13  Swanbourne
# 1892  2025/01/31    Ocean Reef      WATCH AND ACT    15  Swanbourne
# 1893  2025/01/31  Orange Grove             ADVICE    10     Bickley
# 1894  2025/01/31  Orange Grove  EMERGENCY WARNING    13     Bickley
# 1895  2025/01/31  Orange Grove      WATCH AND ACT    17     Bickley
#
# [1896 rows x 5 columns]

# %% [markdown]
# ## Dataset weather

# %%
from google.colab import drive
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt

# %%
# Define the folder path containing the CSV files
folder_path = os.path.join('DATA', 'Weather lengkap')

# Use glob to find all CSV files in the folder
all_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Create an empty list to store dataframes
df_list = []

# Loop through all CSV files
for filename in all_files:
    try:
        # Read each CSV file into a dataframe
        df = pd.read_csv(filename, sep=';', encoding='ISO-8859-1', on_bad_lines='skip')
        df_list.append(df)
        df['station'] = os.path.basename(filename)
    except pd.errors.ParserError:
        print(f"Error parsing file: {filename}. Skipping this file.")
    except Exception as e:  # Catch other potential errors during file reading
        print(f"An error occurred while processing {filename}: {e}")


# Concatenate all dataframes in the list
if df_list:  # Check if df_list is not empty
    combined_df = pd.concat(df_list, ignore_index=True)

    # Now you can work with combined_df, e.g., export to CSV
    combined_df.to_csv('combined_data.csv', index=False)
    print("Combined data saved to combined_data.csv")
else:
    print("No valid CSV files found in the specified directory.")
# Out:
# Combined data saved to combined_data.csv

# %%
combined_df = pd.read_csv('/content/combined_data.csv', sep=',',  encoding='ISO-8859-1')
combined_df
# Out:
#      Unnamed: 0,Date,Minimum temperature (Â°C),Maximum temperature (Â°C),Rainfall (mm),Evaporation (mm),Sunshine (hours),Direction of maximum wind gust ,Speed of maximum wind gust (km/h),Time of maximum wind gust,9am Temperature (Â°C),9am relative humidity (%),9am cloud amount (oktas),9am wind direction,9am wind speed (km/h),9am MSL pressure (hPa),3pm Temperature (Â°C),3pm relative humidity (%),3pm cloud amount (oktas),3pm wind direction,3pm wind speed (km/h),3pm MSL pressure (hPa)  \
# 0     ,2023-12-1,17.0,34.6,0.0,,12.6,SW,41.0,16:14,2...
# 1     ,2023-12-2,17.2,26.5,0.0,,10.9,W,41.0,12:02,23...
# 2     ,2023-12-3,19.5,26.3,0.0,,9.8,WSW,35.0,13:53,2...
# 3     ,2023-12-4,16.6,26.2,0.0,,11.8,SW,41.0,15:58,2...
# 4     ,2023-12-5,15.3,28.7,0.0,,9.4,SSW,46.0,16:52,2...
# ...                                                 ...
# 4610  ,2025-01-27,17.3,28.5,0.0,,,ESE,39.0,07:58,22....
# 4611  ,2025-01-28,18.0,,0.0,,,,,,24.8,44.0,,ESE,20.0...
# ...

# %% [markdown]
# ## Merged Dataset

# %%
# data
file_path = os.path.join(folder_path, 'combined_data fixed.csv')
weather = pd.read_csv(file_path, sep=';')# on_bad_lines='skip') # on_bad_lines='skip' will skip lines that cause errors.
weather['Date'] = pd.to_datetime(weather['Date'], format='%d/%m/%Y').dt.strftime('%Y/%m/%d')
weather['Time of maximum wind gust'] = pd.to_datetime(weather['Time of maximum wind gust'], errors='coerce').dt.hour
weather.loc[weather['Time of maximum wind gust'] == 0, 'Time of maximum wind gust'] = 24
weather
# Out:
# <ipython-input-67-699ede162d47>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weather['Time of maximum wind gust'] = pd.to_datetime(weather['Time of maximum wind gust'], errors='coerce').dt.hour
#             Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     2023/12/01                      17.0                      34.6
# 1     2023/12/02                      17.2                      26.5
# 2     2023/12/03                      19.5                      26.3
# 3     2023/12/04                      16.6                      26.2
# 4     2023/12/05                      15.3                      28.7
# ...          ...                       ...                       ...
# 4610  2025/01/27                      17.3                      28.5
# 4611  2025/01/28                      18.0                       NaN
# ...

# %%
# Rename columns
new_column_names = {
    'Minimum temperature (°C)': 'Minimum Temperature',
    'Maximum temperature (°C)': 'Maximum Temperature',
    'Rainfall (mm)': 'Rainfall',
    'Evaporation (mm)': 'Evaporation',
    'Sunshine (hours)': 'Sunshine',
    'Direction of maximum wind gust ': 'Direction Max Wind Gust',
    'Speed of maximum wind gust (km/h)': 'Speed Max Wind Gust',
    'Time of maximum wind gust': 'Time Max Wind Gust'
}
weather = weather.rename(columns=new_column_names)

# Display or further process the combined DataFrame
weather
# Out:
#             Date  Minimum Temperature  Maximum Temperature  Rainfall  \
# 0     2023/12/01                 17.0                 34.6       0.0
# 1     2023/12/02                 17.2                 26.5       0.0
# 2     2023/12/03                 19.5                 26.3       0.0
# 3     2023/12/04                 16.6                 26.2       0.0
# 4     2023/12/05                 15.3                 28.7       0.0
# ...          ...                  ...                  ...       ...
# 4610  2025/01/27                 17.3                 28.5       0.0
# 4611  2025/01/28                 18.0                  NaN       0.0
# 4612  2025/01/29                  NaN                  NaN       NaN
# 4613  2025/01/30                  NaN                  NaN       0.0
# 4614  2025/01/31                  NaN                  NaN       0.0
#
#       Evaporation  Sunshine Direction Max Wind Gust  Speed Max Wind Gust  \
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4615 entries, 0 to 4614
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       4615 non-null   object
#  1   Minimum Temperature        4591 non-null   float64
#  2   Maximum Temperature        4573 non-null   float64
#  3   Rainfall                   4139 non-null   float64
#  4   Evaporation                1269 non-null   float64
#  5   Sunshine                   2140 non-null   float64
#  6   Direction Max Wind Gust    4485 non-null   object
#  7   Speed Max Wind Gust        4486 non-null   float64
#  8   Time Max Wind Gust         4506 non-null   float64
#  9   9am Temperature (°C)       4603 non-null   float64
#  10  9am relative humidity (%)  4600 non-null   float64
#  11  9am cloud amount (oktas)   1602 non-null   float64
#  12  9am wind direction         4601 non-null   object
# ...

# %%
clean_df['Date'] = pd.to_datetime(clean_df['Date']).dt.strftime('%Y/%m/%d')
# Menambahkan kolom kosong kedalam dataframe 'burnt'
for col_name in ['Minimum Temperature', 'Maximum Temperature', 'Rainfall', 'Evaporation', 'Sunshine', 'Direction Max Wind Gust', 'Speed Max Wind Gust', 'Time Max Wind Gust']:
    clean_df[col_name] = '' # None or '' for empty string
clean_df
# Out:
#             Date        suburb             status  time     station  \
# 0     2023/12/01     Hamersley             ADVICE    10       Perth
# 1     2023/12/01    Mariginiup             ADVICE    10      Pearce
# 2     2023/12/01      Wanneroo             ADVICE    10       Perth
# 3     2023/12/02     Hamersley             ADVICE    10       Perth
# 4     2023/12/02    Mariginiup             ADVICE    10      Pearce
# ...          ...           ...                ...   ...         ...
# 1891  2025/01/31    Ocean Reef  EMERGENCY WARNING    13  Swanbourne
# 1892  2025/01/31    Ocean Reef      WATCH AND ACT    15  Swanbourne
# 1893  2025/01/31  Orange Grove             ADVICE    10     Bickley
# 1894  2025/01/31  Orange Grove  EMERGENCY WARNING    13     Bickley
# 1895  2025/01/31  Orange Grove      WATCH AND ACT    17     Bickley
#
#      Minimum Temperature Maximum Temperature Rainfall Evaporation Sunshine  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1896 non-null   object
#  1   suburb                   1896 non-null   object
#  2   status                   1896 non-null   object
#  3   time                     1896 non-null   int32
#  4   station                  1896 non-null   object
#  5   Minimum Temperature      1896 non-null   object
#  6   Maximum Temperature      1896 non-null   object
#  7   Rainfall                 1896 non-null   object
#  8   Evaporation              1896 non-null   object
#  9   Sunshine                 1896 non-null   object
#  10  Direction Max Wind Gust  1896 non-null   object
#  11  Speed Max Wind Gust      1896 non-null   object
#  12  Time Max Wind Gust       1896 non-null   object
# dtypes: int32(1), object(12)
# memory usage: 185.3+ KB

# %%
# Iterate through the 'clean_df' DataFrame
for index, row in clean_df.iterrows():
    date = row['Date']
    station = row['station']
    matching_rows = weather[(weather['Date'] == date) & (weather['station'] == station)]

    # If a match is found, update the corresponding columns in 'clean_df'
    if not matching_rows.empty:
        for col_name in ['Minimum Temperature', 'Maximum Temperature', 'Rainfall', 'Evaporation', 'Sunshine', 'Direction Max Wind Gust', 'Speed Max Wind Gust', 'Time Max Wind Gust']:
            clean_df.loc[index, col_name] = matching_rows.iloc[0][col_name]

clean_df
# Out:
#             Date        suburb             status  time     station  \
# 0     2023/12/01     Hamersley             ADVICE    10       Perth
# 1     2023/12/01    Mariginiup             ADVICE    10      Pearce
# 2     2023/12/01      Wanneroo             ADVICE    10       Perth
# 3     2023/12/02     Hamersley             ADVICE    10       Perth
# 4     2023/12/02    Mariginiup             ADVICE    10      Pearce
# ...          ...           ...                ...   ...         ...
# 1891  2025/01/31    Ocean Reef  EMERGENCY WARNING    13  Swanbourne
# 1892  2025/01/31    Ocean Reef      WATCH AND ACT    15  Swanbourne
# 1893  2025/01/31  Orange Grove             ADVICE    10     Bickley
# 1894  2025/01/31  Orange Grove  EMERGENCY WARNING    13     Bickley
# 1895  2025/01/31  Orange Grove      WATCH AND ACT    17     Bickley
#
#      Minimum Temperature Maximum Temperature Rainfall Evaporation Sunshine  \
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1896 non-null   object
#  1   suburb                   1896 non-null   object
#  2   status                   1896 non-null   object
#  3   time                     1896 non-null   int32
#  4   station                  1896 non-null   object
#  5   Minimum Temperature      1866 non-null   object
#  6   Maximum Temperature      1862 non-null   object
#  7   Rainfall                 1789 non-null   object
#  8   Evaporation              778 non-null    object
#  9   Sunshine                 1409 non-null   object
#  10  Direction Max Wind Gust  1833 non-null   object
#  11  Speed Max Wind Gust      1833 non-null   object
#  12  Time Max Wind Gust       1833 non-null   object
# dtypes: int32(1), object(12)
# memory usage: 185.3+ KB

# %%
df= clean_df.copy()

# %%
# Pastikan kolom numerik dikonversi ke tipe data float (karena masih dalam bentuk object)
numeric_columns = [
    "Minimum Temperature", "Maximum Temperature", "Rainfall",
    "Evaporation", "Sunshine", "Speed Max Wind Gust", "Time Max Wind Gust"
]

df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Jika masih ada nilai null (karena semua dalam grup adalah NaN), isi dengan median keseluruhan kolom
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

df
# Out:
#             Date        suburb             status  time     station  \
# 0     2023/12/01     Hamersley             ADVICE    10       Perth
# 1     2023/12/01    Mariginiup             ADVICE    10      Pearce
# 2     2023/12/01      Wanneroo             ADVICE    10       Perth
# 3     2023/12/02     Hamersley             ADVICE    10       Perth
# 4     2023/12/02    Mariginiup             ADVICE    10      Pearce
# ...          ...           ...                ...   ...         ...
# 1891  2025/01/31    Ocean Reef  EMERGENCY WARNING    13  Swanbourne
# 1892  2025/01/31    Ocean Reef      WATCH AND ACT    15  Swanbourne
# 1893  2025/01/31  Orange Grove             ADVICE    10     Bickley
# 1894  2025/01/31  Orange Grove  EMERGENCY WARNING    13     Bickley
# 1895  2025/01/31  Orange Grove      WATCH AND ACT    17     Bickley
#
#       Minimum Temperature  Maximum Temperature  Rainfall  Evaporation  \
# 0                    18.6                 35.3       0.0          7.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1896 non-null   object
#  1   suburb                   1896 non-null   object
#  2   status                   1896 non-null   object
#  3   time                     1896 non-null   int32
#  4   station                  1896 non-null   object
#  5   Minimum Temperature      1896 non-null   float64
#  6   Maximum Temperature      1896 non-null   float64
#  7   Rainfall                 1896 non-null   float64
#  8   Evaporation              1896 non-null   float64
#  9   Sunshine                 1896 non-null   float64
#  10  Direction Max Wind Gust  1833 non-null   object
#  11  Speed Max Wind Gust      1896 non-null   float64
#  12  Time Max Wind Gust       1896 non-null   float64
# dtypes: float64(7), int32(1), object(5)
# ...

# %%
df.describe()
# Out:
#               time  Minimum Temperature  Maximum Temperature     Rainfall  \
# count  1896.000000          1896.000000          1896.000000  1896.000000
# mean     12.874473            19.208914            34.171097     0.020570
# std       5.271225             3.186535             5.123666     0.325485
# min       1.000000             5.200000            14.100000     0.000000
# 25%      10.000000            17.800000            31.600000     0.000000
# 50%      13.000000            19.200000            33.300000     0.000000
# 75%      15.000000            21.500000            38.400000     0.000000
# max      24.000000            28.700000            45.100000    11.200000
#
#        Evaporation     Sunshine  Speed Max Wind Gust  Time Max Wind Gust
# count  1896.000000  1896.000000          1896.000000         1896.000000
# mean     10.189557    11.675000            42.006857           13.896624
# std       1.046263     1.353517             9.529316            6.132475
# ...

# %%
import numpy as np
# Ganti nilai kosong tersembunyi menjadi NaN
df.replace(["", " ", "NULL", "-"], np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1896 non-null   object
#  1   suburb                   1896 non-null   object
#  2   status                   1896 non-null   object
#  3   time                     1896 non-null   int32
#  4   station                  1896 non-null   object
#  5   Minimum Temperature      1896 non-null   float64
#  6   Maximum Temperature      1896 non-null   float64
#  7   Rainfall                 1896 non-null   float64
#  8   Evaporation              1896 non-null   float64
#  9   Sunshine                 1896 non-null   float64
#  10  Direction Max Wind Gust  1697 non-null   object
#  11  Speed Max Wind Gust      1896 non-null   float64
#  12  Time Max Wind Gust       1896 non-null   float64
# dtypes: float64(7), int32(1), object(5)
# ...

# %%
# prompt: drop nilai null pada direction max wind gust

# Drop rows with null values in the 'Direction Max Wind Gust' column
df = df.dropna(subset=['Direction Max Wind Gust'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1697 entries, 0 to 1895
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1697 non-null   object
#  1   suburb                   1697 non-null   object
#  2   status                   1697 non-null   object
#  3   time                     1697 non-null   int32
#  4   station                  1697 non-null   object
#  5   Minimum Temperature      1697 non-null   float64
#  6   Maximum Temperature      1697 non-null   float64
#  7   Rainfall                 1697 non-null   float64
#  8   Evaporation              1697 non-null   float64
#  9   Sunshine                 1697 non-null   float64
#  10  Direction Max Wind Gust  1697 non-null   object
#  11  Speed Max Wind Gust      1697 non-null   float64
#  12  Time Max Wind Gust       1697 non-null   float64
# dtypes: float64(7), int32(1), object(5)
# ...

# %%
df
# Out:
#             Date        suburb             status  time     station  \
# 0     2023/12/01     Hamersley             ADVICE    10       Perth
# 1     2023/12/01    Mariginiup             ADVICE    10      Pearce
# 2     2023/12/01      Wanneroo             ADVICE    10       Perth
# 3     2023/12/02     Hamersley             ADVICE    10       Perth
# 4     2023/12/02    Mariginiup             ADVICE    10      Pearce
# ...          ...           ...                ...   ...         ...
# 1891  2025/01/31    Ocean Reef  EMERGENCY WARNING    13  Swanbourne
# 1892  2025/01/31    Ocean Reef      WATCH AND ACT    15  Swanbourne
# 1893  2025/01/31  Orange Grove             ADVICE    10     Bickley
# 1894  2025/01/31  Orange Grove  EMERGENCY WARNING    13     Bickley
# 1895  2025/01/31  Orange Grove      WATCH AND ACT    17     Bickley
#
#       Minimum Temperature  Maximum Temperature  Rainfall  Evaporation  \
# 0                    18.6                 35.3       0.0          7.6
# ...

# %%
# Export the DataFrame 'df' as a CSV file named 'dataset.csv'
df.to_csv('dataset.csv', index=False)
